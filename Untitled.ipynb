# %%
from importlib import reload
from torch.utils.data import DataLoader
import torch
import torchvision
from torchvision.transforms import ToTensor, RandomCrop, Compose
from torch import nn, optim
import numpy as np
import matplotlib.pyplot as plt
import utils_lib.data
from utils_lib import  utils
import torchvision.transforms.functional as TF
from torchvision import transforms

# %%
print(1)
# Out:
# 1

# %%
nn.Linear(3, 3).weight.data
# Out:
# tensor([[-0.1986, -0.2481, -0.0610],
#         [ 0.1402,  0.2965, -0.2709],
#         [ 0.0667,  0.3694,  0.1531]])

# %%
nn.Conv2d(1, 2, kernel_size = 4, stride = 1).weight.data.size()
# Out:
# torch.Size([2, 1, 4, 4])

# %%
x = [1,2,3]
y = [3,2,1]
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.title("Accuracy")
plt.plot(x, label = 'x')
plt.plot(y, label = 'y')
plt.legend()

plt.subplot(1,2,2)
plt.title("Loss")
plt.plot(x, label = 'x')
plt.legend()

plt.show()

# %%
a = torch.tensor([1,2,3])

# %%
x, y, z = map(int, a)

# %%
x , y, z
# Out:
# (1, 2, 3)

# %%
a = torch.ones(2)

# %%
hash(a)
# Out:
# 140598964401488

# %%
b = torch.ones(2)

# %%
hash(b)
# Out:
# 140598959368384

# %%
hash(b) == hash(a)
# Out:
# False

# %%
tuple(a)
# Out:
# (tensor(1.), tensor(1.))

# %%
a.numpy()
# Out:
# array([1., 1.], dtype=float32)

# %%
hash(a.numpy().tobytes()) == hash(b.numpy().tobytes())
# Out:
# True

# %%
a = set([123])
b = set([123, 23])

# %%
size = 12
transform = transforms.Compose([
    transforms.RandomResizedCrop((size, size), scale = (0.05, 1)),
    transforms.ToTensor(),
])

data1 = torchvision.datasets.VOCDetection(root = 'data/VOC',
                                     image_set = 'train',
                                     transform = transform,
                                     download = False)
data2 = torchvision.datasets.VOCDetection(root = 'data/VOC',
                                     image_set = 'trainval',
                                     transform = transform,
                                     download = False)
data3 = torchvision.datasets.VOCDetection(root = 'data/VOC',
                                     image_set = 'val',
                                     transform = transform,
                                     download = False)
data = data1 + data2+ data3

# %%
utils.plt_tensor(data[1][0])

# %%
utils.plt_tensor(data[1][0])

# %%
len([(data[i][0], torch.tensor(0, dtype = torch.int64)) for i in range(len(data)) if not utils_lib.data.has_person(data[i][1])])
# Out:
# 14332

# %%
x = TF.to_tensor(data[1][0])

# %%
x.shape
# Out:
# torch.Size([3, 327, 500])

# %%
n_train_no_person = 3575

# %%
TF.randomcrop
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-79055a6b7e86> in <module>
# ----> 1 TF.randomcrop
#
# AttributeError: module 'torchvision.transforms.functional' has no attribute 'randomcrop'

# %%
import torchvision.models as models
resnet18 = models.resnet18(pretrained=True)
alexnet = models.alexnet(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /a/home/cc/students/cs/eladb3/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# ...
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /a/home/cc/students/cs/eladb3/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# ...

# %%
resnet = resnet18.cuda()

# %%
from torchsummary import summary

# %%
summary(resnet18, input_size = (3,224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
# ...

# %%
resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
a
# Out:
# [1, 2, 3]

# %%
a = torch.tensor([[1,2,3], [2,4,5], [3,45,2]])

# %%
a[torch.randperm(a.size(0)), :]
# Out:
# tensor([[ 2,  4,  5],
#         [ 3, 45,  2],
#         [ 1,  2,  3]])
